# %%
import numpy as np
import datetime 
import matplotlib.pyplot as plt
import os
import json
import subprocess

OUT_DAY = 'arr_day.npy' #the output files containing integrated power and metadata for each sweep-spectrum on record
OUT_NIGHT = 'arr_night.npy'
SUNSET_TIMETABLE = np.genfromtxt('/lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring/HERA_daily_RFI/HERA_sunrise_sunset_annual.csv', dtype=str,delimiter=',') # Col 0: Month-day (mmdd), Col 1: Sunrise (hhmm), Col 2: Sunset (hhmm)
STR_DAY = os.environ['which_day']
DEBUG = True

def file_flush():
	if DEBUG: print('flushing temporary and output files...')
	open(OUT_DAY, 'w').close()
	open(OUT_NIGHT, 'w').close()
	if DEBUG: print('done.')

def delta_hours_minutes(td):
    return td.seconds//3600, (td.seconds//60)%60

def recursive_key_search(dat, key): #https://stackoverflow.com/questions/9807634/find-all-occurrences-of-a-key-in-nested-python-dictionaries-and-lists
#sum_dbm_recursive_key_search(dat, key): #https://stackoverflow.com/questions/9807634/find-all-occurrences-of-a-key-in-nested-python-dictionaries-and-lists
    if key in dat:
        yield dat[key]
    for k in dat:
        if isinstance(dat[k], list):
            for i in dat[k]:
                for j in recursive_key_search(i):
                    yield j

def time_in_rids_fmt(datetime_time): # convert datetime.datetime.now() time into the RIDZ-requested format
	str_iso = datetime_time.isoformat(' ')
	str_time_rids = str( str_iso[0:4] + str_iso[5:7] + str_iso[8:10] + '-' + str_iso[11:13]+str_iso[14:16]+str_iso[17:19])
	return str_time_rids

def sum_array_of_dbm(arr):
	val_sum = 10.*np.log10(np.sum(np.power(10,np.array(arr)/10.)))
	return val_sum

def trunc_time(dt):
    dt_trunc = datetime.date(dt.day, dt.hour, dt.minute, dt.second)
    return dt_trunc


def calc_wf_and_integrated_power():
    ## check these fileid aren't in the processed_sessid.txt file
    processed_file_dir = os.path.dirname(os.environ['DATA_PATH'])
    processed_fileid = np.loadtxt(os.path.join(processed_file_dir, 'processed_fileid.txt'), dtype=np.int)
    if DEBUG: 
        print('NOTE: Since in DEBUG mode, Will reprocess files if instructed.')
        
    # filter out sessions already processed
    unprocessed_files = []
    pathname = []
    for diritem in os.listdir(os.environ['staging_dir']):
        if DEBUG: 
            print('in ipynb, staging_dir is: '+str(os.environ['staging_dir']))
        if os.path.isdir(diritem) or str(diritem).isdigit():
            pathname = str(str(os.environ['staging_dir'])+'/'+str(diritem)+'/')
            print('  '+str(diritem)+' considered to be a dir.')
            for dir_file in os.listdir(pathname):
                name=str(dir_file)#file["name"])
                if DEBUG: print('   In dir, pathname: '+str(pathname)+', dirfile: '+str(name))
                fileid = int(name[int(name.find('.')+1):name.find('-')])
                if (fileid not in processed_fileid) or DEBUG:
                    unprocessed_files.append(name)
                    
        else:
            pathname = str(os.environ['staging_dir']+'/')
            name=str(diritem)#file["name"])
            if DEBUG: 
                print('  '+str(name)+' is thought to be a file, not a directory.')
                print('    diritem is a file, name: '+str(name))
            fileid = int(name[int(name.find('.')+1):name.find('-')])
            if (fileid not in processed_fileid) or DEBUG:
                unprocessed_files.append(name)

    if DEBUG: 
        print('List of unprocessed files (or all files if DEBUG): '+str(unprocessed_files))
        print('Ready to analyze files in pathname "'+str(pathname)+'".')
        print('launching subprocess...')
    # %cd {pathname}
    str_args = str( str( ','.join([str(s) for s in os.listdir(pathname) if s.endswith('.ridz') and STR_DAY in s])))
    if DEBUG: print('str_args: '+str(str_args))
    # %run ~/anaconda/envs/py2.7env/bin/sp_rawview --wf val {str_args} 
    # %run ~/anaconda/envs/py2.7env/bin/sp_rawview --totalpower val {str_args}
    if DEBUG: print('    ...subprocess complete.')

    return  

#For the day in question, figure out when sunset and sunrise were. 
col_date,col_key = np.where(SUNSET_TIMETABLE == STR_DAY[4:]) #find mmdd, but it could also be a time
sunrise = datetime.datetime.strptime( str(str(STR_DAY[:4])+str(STR_DAY[4:])+'-'+str(SUNSET_TIMETABLE[int(col_date[col_key==0])][1])) ,'%Y%m%d-%H%M')
sunset = datetime.datetime.strptime( str(str(STR_DAY[:4])+str(STR_DAY[4:])+'-'+str(SUNSET_TIMETABLE[int(col_date[col_key==0])][2])) ,'%Y%m%d-%H%M')
delta_hour, delta_minute = delta_hours_minutes((sunset-sunrise))
#Arrays containing data from each sweep measurement, sorted by whether the data occured in the daytime or nighttime.
arr_day=[] # [datetime.datetime object], [float(integrated power)]
arr_night=[]


file_flush() # Make sure output files aren't reused with old data in them.
calc_wf_and_integrated_power()
# Out:
# flushing temporary and output files...
# done.
# NOTE: Since in DEBUG mode, Will reprocess files if instructed.
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-030000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-030000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-120000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-120000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-230000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-230000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-050000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-050000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-110000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-110000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-060000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-060000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-150000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-150000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-160000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-160000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-040000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-040000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-140000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-140000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-080000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-080000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-170000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-170000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-090000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-090000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-190000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-190000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-200000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-200000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-020000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-020000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-180000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-180000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-130000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-130000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-010000.n118.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-010000.n118.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-000000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-000000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-100000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-100000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-210000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-210000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-070000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-070000.n120.None.ridz
# in ipynb, staging_dir is: /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
#   SDR_SpectrumPeak.20181024-220000.n120.None.ridz is thought to be a file, not a directory.
#     diritem is a file, name: SDR_SpectrumPeak.20181024-220000.n120.None.ridz
# List of unprocessed files (or all files if DEBUG): ['SDR_SpectrumPeak.20181024-030000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-120000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-230000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-050000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-110000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-060000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-150000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-160000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-040000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-140000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-080000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-170000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-090000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-190000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-200000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-020000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-180000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-130000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-010000.n118.None.ridz', 'SDR_SpectrumPeak.20181024-000000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-100000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-210000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-070000.n120.None.ridz', 'SDR_SpectrumPeak.20181024-220000.n120.None.ridz']
# Ready to analyze files in pathname "/lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024/".
# launching subprocess...
# /lustre/aoc/projects/hera/ajosaiti/SDR_RFI_monitoring_staging/20181024
# str_args: SDR_SpectrumPeak.20181024-030000.n120.None.ridz,SDR_SpectrumPeak.20181024-120000.n120.None.ridz,SDR_SpectrumPeak.20181024-230000.n120.None.ridz,SDR_SpectrumPeak.20181024-050000.n120.None.ridz,SDR_SpectrumPeak.20181024-110000.n120.None.ridz,SDR_SpectrumPeak.20181024-060000.n120.None.ridz,SDR_SpectrumPeak.20181024-150000.n120.None.ridz,SDR_SpectrumPeak.20181024-160000.n120.None.ridz,SDR_SpectrumPeak.20181024-040000.n120.None.ridz,SDR_SpectrumPeak.20181024-140000.n120.None.ridz,SDR_SpectrumPeak.20181024-080000.n120.None.ridz,SDR_SpectrumPeak.20181024-170000.n120.None.ridz,SDR_SpectrumPeak.20181024-090000.n120.None.ridz,SDR_SpectrumPeak.20181024-190000.n120.None.ridz,SDR_SpectrumPeak.20181024-200000.n120.None.ridz,SDR_SpectrumPeak.20181024-020000.n120.None.ridz,SDR_SpectrumPeak.20181024-180000.n120.None.ridz,SDR_SpectrumPeak.20181024-130000.n120.None.ridz,SDR_SpectrumPeak.20181024-010000.n118.None.ridz,SDR_SpectrumPeak.20181024-000000.n120.None.ridz,SDR_SpectrumPeak.20181024-100000.n120.None.ridz,SDR_SpectrumPeak.20181024-210000.n120.None.ridz,SDR_SpectrumPeak.20181024-070000.n120.None.ridz,SDR_SpectrumPeak.20181024-220000.n120.None.ridz
# Need to properly do this, but for now = 0.0
# Reading SDR_SpectrumPeak.20181024-030000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-120000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-230000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-050000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-110000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-060000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-150000.n120.None.ridz
# ValueErrorTraceback (most recent call last)
# /users/ajosaiti/anaconda/envs/py2.7env/bin/sp_rawview.py in <module>()
#      71     # Read in data
#      72     r = features.spectrum_peak.SpectrumPeak()
# ---> 73     r.reader(args.file)
#      74     # Set up data parameters for plot
#      75     s = features.sp_handling_raw.SPHandling(r)
#
# /users/ajosaiti/anaconda/lib/python2.7/site-packages/rids-0.1.dev0-py2.7.egg/rids/features/spectrum_peak.pyc in reader(self, filename, reset)
#     168             print("Reading {}".format(filename))
#     169             self._reader(filename, feature_direct=self.sp__direct_attributes,
# --> 170                          feature_unit=self.sp__unit_attributes)
#     171         # now need to fill in the share_freq feature values, if any
#     172         for ftr in self.feature_sets:
#
# /users/ajosaiti/anaconda/lib/python2.7/site-packages/rids-0.1.dev0-py2.7.egg/rids/rids.pyc in _reader(self, filename, feature_direct, feature_unit)
#     130             r_open = open
#     131         with r_open(filename, 'rb') as f:
# --> 132             data = json.load(f)
#     133         for d, val in six.iteritems(data):
#     134             if d == 'comment':
#
# /users/ajosaiti/anaconda/lib/python2.7/json/__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     289         parse_float=parse_float, parse_int=parse_int,
#     290         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 291         **kw)
#     292
#     293
#
# /users/ajosaiti/anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /users/ajosaiti/anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /users/ajosaiti/anaconda/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded
# Need to properly do this, but for now = 0.0
# Reading SDR_SpectrumPeak.20181024-030000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-120000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-230000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-050000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-110000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-060000.n120.None.ridz
# Reading SDR_SpectrumPeak.20181024-150000.n120.None.ridz
# ValueErrorTraceback (most recent call last)
# /users/ajosaiti/anaconda/envs/py2.7env/bin/sp_rawview.py in <module>()
#      71     # Read in data
#      72     r = features.spectrum_peak.SpectrumPeak()
# ---> 73     r.reader(args.file)
#      74     # Set up data parameters for plot
#      75     s = features.sp_handling_raw.SPHandling(r)
#
# /users/ajosaiti/anaconda/lib/python2.7/site-packages/rids-0.1.dev0-py2.7.egg/rids/features/spectrum_peak.pyc in reader(self, filename, reset)
#     168             print("Reading {}".format(filename))
#     169             self._reader(filename, feature_direct=self.sp__direct_attributes,
# --> 170                          feature_unit=self.sp__unit_attributes)
#     171         # now need to fill in the share_freq feature values, if any
#     172         for ftr in self.feature_sets:
#
# /users/ajosaiti/anaconda/lib/python2.7/site-packages/rids-0.1.dev0-py2.7.egg/rids/rids.pyc in _reader(self, filename, feature_direct, feature_unit)
#     130             r_open = open
#     131         with r_open(filename, 'rb') as f:
# --> 132             data = json.load(f)
#     133         for d, val in six.iteritems(data):
#     134             if d == 'comment':
#
# /users/ajosaiti/anaconda/lib/python2.7/json/__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     289         parse_float=parse_float, parse_int=parse_int,
#     290         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 291         **kw)
#     292
#     293
#
# /users/ajosaiti/anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /users/ajosaiti/anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /users/ajosaiti/anaconda/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded
#     ...subprocess complete.
